# %% [markdown]
# # LDA Topic Modeling and Clustering

# %% [markdown]
# Use the LDA model to create topics, or clusters, present in the dataset using the abstracts of the papers. Each topic corresponds to a set of word-probability pairs, and I chose to use the top 15 highest probability words of each topic to represent the given topic. Each paper is assigned a topic based on how many of the top 15 words of each topic are included in the abstract, and how often.

# %%
# download gensim and wordcloud libraries with
# pip install --upgrade gensim
# pip install wordcloud

# %%
import numpy as np
import pandas as pd
import json
import itertools
import matplotlib.pyplot as plt

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans

from sklearn.cluster import MiniBatchKMeans
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE

import nltk
from nltk.stem.snowball import SnowballStemmer
#from nltk.stem.porter import PorterStemmer
from nltk.corpus import stopwords 
nltk.download('stopwords')
from nltk.tokenize import word_tokenize 
nltk.download('punkt')
from nltk.stem import WordNetLemmatizer 
nltk.download('wordnet')

import re

import gensim
from gensim import corpora, models
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/jayfeng/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /Users/jayfeng/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /Users/jayfeng/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
"""Reads in abstracts.csv and filters out rows with missing values."""

df = pd.read_csv("abstracts.csv")
df = df[df["abstract"] != "NaN"]
df = df.dropna()

# %%
"""Set up stop words, stemmer, and lemmatizer."""

stop_words = set(stopwords.words('english')) 
snowBallStemmer = SnowballStemmer("english")
lemmatizer = WordNetLemmatizer()

# %%
"""Tokenize and clean the abstracts of every paper."""

def tokenize_clean(abstract):
    #tokenizes abstract string
    tokens = word_tokenize(abstract.lower())
    
    #lemmatizes tokens
    counter = 0
    while counter < len(tokens):
        tokens[counter] = lemmatizer.lemmatize(tokens[counter])
        counter += 1
    
    #filters, stems, and lowercases tokens
    filtered_tokens = []
    for i in tokens:
        if i not in stop_words and len(i) > 3 and i != "abstract":
            stemmed_word = snowBallStemmer.stem(i)
            filtered_tokens.append(stemmed_word)
    
    return filtered_tokens

df["abstract tokens"] = df.apply(lambda row: tokenize_clean(row.abstract), axis=1)

# %%
"""Perform LDA topic modelling on a sample of the papers for speed purposes."""

partial_df = df#.sample(3000)

# %%
"""Create a list of lists of cleaned tokens of abstracts"""

partial_texts = []
for index, row in partial_df.iterrows():
    partial_texts.append(row[3])

# %%
"""Use gensim package to perform LDA topic modelling.
Code from https://towardsdatascience.com/topic-modeling-and-latent-dirichlet-allocation-in-python-9bf156893c24
used for reference.
"""

dictionary = corpora.Dictionary(partial_texts)
dictionary.filter_extremes(no_below=3)

corpus = [dictionary.doc2bow(text) for text in partial_texts]

ldamodel = gensim.models.ldamodel.LdaModel(corpus, num_topics=10, id2word = dictionary, passes=50)

# %%
lda_results = ldamodel.show_topics(num_topics=10, num_words=20, formatted=False)
lda_results
# Out:
# [(0,
#   [('patient', 0.048303332),
#    ('covid-19', 0.039030943),
#    ('case', 0.023331147),
#    ('hospit', 0.019981418),
#    ('sever', 0.013059364),
#    ('wuhan', 0.011461586),
#    ('sars-cov-2', 0.010351377),
#    ('rate', 0.010235644),
#    ('china', 0.009309635),
#    ('clinic', 0.008882698),
#    ('studi', 0.008842795),
#    ('diseas', 0.008756813),
#    ('symptom', 0.008755969),
#    ('group', 0.0078052282),
#    ('report', 0.007737698),
#    ('coronavirus', 0.006926259),
#    ('data', 0.0067405896),
#    ('signific', 0.006533356),
#    ('confirm', 0.0063483967),
#    ('conclus', 0.006216904)]),
#  (1,
#   [('group', 0.017595792),
#    ('studi', 0.012785662),
#    ('sampl', 0.012741309),
#    ('calf', 0.011332178),
#    ('temperatur', 0.011162121),
#    ('level', 0.01010971),
#    ('signific', 0.009811813),
#    ('result', 0.009078152),
#    ('contamin', 0.008544441),
#    ('control', 0.007547792),
#    ('increas', 0.007457925),
#    ('serum', 0.00732953),
#    ('effect', 0.0070218216),
#    ('test', 0.006847767),
#    ('heat', 0.0067536286),
#    ('diarrhea', 0.006699297),
#    ('associ', 0.0065673827),
#    ('anim', 0.006406573),
#    ('compar', 0.006000208),
#    ('concentr', 0.005947423)]),
#  (2,
#   [('use', 0.015672656),
#    ('develop', 0.013698284),
#    ('method', 0.010502114),
#    ('diseas', 0.009467901),
#    ('review', 0.009164486),
#    ('system', 0.007905928),
#    ('research', 0.0076172603),
#    ('pathogen', 0.0061317175),
#    ('includ', 0.0060880063),
#    ('studi', 0.005861724),
#    ('provid', 0.00578526),
#    ('approach', 0.005726745),
#    ('potenti', 0.0055954177),
#    ('avail', 0.0055921418),
#    ('clinic', 0.0053467583),
#    ('specif', 0.005124329),
#    ('drug', 0.0050499407),
#    ('also', 0.0048467587),
#    ('applic', 0.004812899),
#    ('articl', 0.004723595)]),
#  (3,
#   [('health', 0.018382236),
#    ('model', 0.0144363735),
#    ('outbreak', 0.011512298),
#    ('diseas', 0.011017336),
#    ('epidem', 0.0099932095),
#    ('public', 0.009270281),
#    ('transmiss', 0.008372521),
#    ('infect', 0.0076535237),
#    ('control', 0.0073048524),
#    ('data', 0.0072627137),
#    ('spread', 0.0071296906),
#    ('popul', 0.007087208),
#    ('number', 0.006744252),
#    ('measur', 0.0065817498),
#    ('countri', 0.0063720318),
#    ('emerg', 0.0062808734),
#    ('infecti', 0.0057563605),
#    ('effect', 0.0056422185),
#    ('case', 0.0056147384),
#    ('use', 0.005501736)]),
#  (4,
#   [('virus', 0.039086007),
#    ('respiratori', 0.034596678),
#    ('infect', 0.031707622),
#    ('influenza', 0.027427088),
#    ('detect', 0.023223575),
#    ('child', 0.019252045),
#    ('viral', 0.017666645),
#    ('sampl', 0.013898697),
#    ('clinic', 0.011713803),
#    ('test', 0.0116910245),
#    ('patient', 0.010481538),
#    ('studi', 0.009904711),
#    ('result', 0.009526048),
#    ('pneumonia', 0.008963739),
#    ('assay', 0.008878123),
#    ('pathogen', 0.008603881),
#    ('posit', 0.008581786),
#    ('acut', 0.0073740245),
#    ('method', 0.007047725),
#    ('caus', 0.006711549)]),
#  (5,
#   [('cell', 0.029473633),
#    ('infect', 0.024888942),
#    ('respons', 0.016179828),
#    ('immun', 0.015798882),
#    ('express', 0.011031168),
#    ('diseas', 0.010872397),
#    ('activ', 0.009938112),
#    ('mous', 0.009443394),
#    ('lung', 0.0070795054),
#    ('increas', 0.0068612574),
#    ('studi', 0.0067970967),
#    ('level', 0.006376446),
#    ('effect', 0.0060836),
#    ('role', 0.0060755257),
#    ('induc', 0.0058840704),
#    ('sever', 0.0055876765),
#    ('cytokin', 0.005539882),
#    ('viral', 0.0054565663),
#    ('mechan', 0.0054374784),
#    ('result', 0.005348044)]),
#  (6,
#   [('virus', 0.03277656),
#    ('sequenc', 0.024082564),
#    ('gene', 0.017971652),
#    ('genom', 0.01626717),
#    ('strain', 0.015860388),
#    ('human', 0.011709478),
#    ('analysi', 0.010870508),
#    ('speci', 0.010377648),
#    ('isol', 0.008788477),
#    ('genet', 0.008465063),
#    ('viral', 0.008349255),
#    ('pathogen', 0.00774463),
#    ('host', 0.0076906634),
#    ('studi', 0.0076464307),
#    ('identifi', 0.007618333),
#    ('differ', 0.0072463597),
#    ('anim', 0.006014568),
#    ('show', 0.0056480947),
#    ('coronavirus', 0.005632314),
#    ('high', 0.0056256647)]),
#  (7,
#   [('protein', 0.036276516),
#    ('virus', 0.022652429),
#    ('viral', 0.017604625),
#    ('cell', 0.014355274),
#    ('replic', 0.011277514),
#    ('structur', 0.01121451),
#    ('interact', 0.010076659),
#    ('host', 0.010071036),
#    ('activ', 0.009944507),
#    ('function', 0.009203321),
#    ('bind', 0.008552608),
#    ('express', 0.0075365705),
#    ('infect', 0.007501749),
#    ('membran', 0.0073668556),
#    ('domain', 0.0066840923),
#    ('target', 0.006380565),
#    ('cellular', 0.0063496525),
#    ('inhibit', 0.005964132),
#    ('mechan', 0.005877763),
#    ('role', 0.0058749565)]),
#  (8,
#   [('coronavirus', 0.040138956),
#    ('sar', 0.037746243),
#    ('mers-cov', 0.03622341),
#    ('respiratori', 0.031359915),
#    ('syndrom', 0.029602824),
#    ('sars-cov', 0.027278047),
#    ('activ', 0.017082147),
#    ('sever', 0.016723758),
#    ('compound', 0.016100425),
#    ('acut', 0.015343837),
#    ('middl', 0.015331838),
#    ('east', 0.014536756),
#    ('mer', 0.01303721),
#    ('human', 0.0117418375),
#    ('antivir', 0.009791108),
#    ('camel', 0.008085041),
#    ('infect', 0.0076245377),
#    ('inhibitor', 0.00759529),
#    ('drug', 0.0073646936),
#    ('emerg', 0.006031344)]),
#  (9,
#   [('vaccin', 0.0327157),
#    ('cell', 0.02429572),
#    ('virus', 0.023089457),
#    ('antibodi', 0.020859491),
#    ('infect', 0.014541659),
#    ('immun', 0.013580697),
#    ('use', 0.012552878),
#    ('protein', 0.011575092),
#    ('antigen', 0.009066316),
#    ('respons', 0.008939082),
#    ('effect', 0.008607956),
#    ('assay', 0.008351873),
#    ('result', 0.008108281),
#    ('protect', 0.00806595),
#    ('express', 0.007765253),
#    ('develop', 0.0074834567),
#    ('neutral', 0.0068151266),
#    ('high', 0.0067088716),
#    ('studi', 0.0067050797),
#    ('mous', 0.0065437583)])]

# %%
"""Create topic_words, a list of buckets of words that represent each topic."""

topic_words = []
#i is each topic
for i in lda_results:
    topic_i_words = []
    word_pairs = i[1]
    #j is the list of word-probability pairs (we don't care about the probabilities here)
    for j in word_pairs:
        topic_i_words.append(j[0])
    topic_words.append(topic_i_words)
        
topic_words
# Out:
# [['patient',
#   'covid-19',
#   'case',
#   'hospit',
#   'sever',
#   'wuhan',
#   'sars-cov-2',
#   'rate',
#   'china',
#   'clinic',
#   'studi',
#   'diseas',
#   'symptom',
#   'group',
#   'report',
#   'coronavirus',
#   'data',
#   'signific',
#   'confirm',
#   'conclus'],
#  ['group',
#   'studi',
#   'sampl',
#   'calf',
#   'temperatur',
#   'level',
#   'signific',
#   'result',
#   'contamin',
#   'control',
#   'increas',
#   'serum',
#   'effect',
#   'test',
#   'heat',
#   'diarrhea',
#   'associ',
#   'anim',
#   'compar',
#   'concentr'],
#  ['use',
#   'develop',
#   'method',
#   'diseas',
#   'review',
#   'system',
#   'research',
#   'pathogen',
#   'includ',
#   'studi',
#   'provid',
#   'approach',
#   'potenti',
#   'avail',
#   'clinic',
#   'specif',
#   'drug',
#   'also',
#   'applic',
#   'articl'],
#  ['health',
#   'model',
#   'outbreak',
#   'diseas',
#   'epidem',
#   'public',
#   'transmiss',
#   'infect',
#   'control',
#   'data',
#   'spread',
#   'popul',
#   'number',
#   'measur',
#   'countri',
#   'emerg',
#   'infecti',
#   'effect',
#   'case',
#   'use'],
#  ['virus',
#   'respiratori',
#   'infect',
#   'influenza',
#   'detect',
#   'child',
#   'viral',
#   'sampl',
#   'clinic',
#   'test',
#   'patient',
#   'studi',
#   'result',
#   'pneumonia',
#   'assay',
#   'pathogen',
#   'posit',
#   'acut',
#   'method',
#   'caus'],
#  ['cell',
#   'infect',
#   'respons',
#   'immun',
#   'express',
#   'diseas',
#   'activ',
#   'mous',
#   'lung',
#   'increas',
#   'studi',
#   'level',
#   'effect',
#   'role',
#   'induc',
#   'sever',
#   'cytokin',
#   'viral',
#   'mechan',
#   'result'],
#  ['virus',
#   'sequenc',
#   'gene',
#   'genom',
#   'strain',
#   'human',
#   'analysi',
#   'speci',
#   'isol',
#   'genet',
#   'viral',
#   'pathogen',
#   'host',
#   'studi',
#   'identifi',
#   'differ',
#   'anim',
#   'show',
#   'coronavirus',
#   'high'],
#  ['protein',
#   'virus',
#   'viral',
#   'cell',
#   'replic',
#   'structur',
#   'interact',
#   'host',
#   'activ',
#   'function',
#   'bind',
#   'express',
#   'infect',
#   'membran',
#   'domain',
#   'target',
#   'cellular',
#   'inhibit',
#   'mechan',
#   'role'],
#  ['coronavirus',
#   'sar',
#   'mers-cov',
#   'respiratori',
#   'syndrom',
#   'sars-cov',
#   'activ',
#   'sever',
#   'compound',
#   'acut',
#   'middl',
#   'east',
#   'mer',
#   'human',
#   'antivir',
#   'camel',
#   'infect',
#   'inhibitor',
#   'drug',
#   'emerg'],
#  ['vaccin',
#   'cell',
#   'virus',
#   'antibodi',
#   'infect',
#   'immun',
#   'use',
#   'protein',
#   'antigen',
#   'respons',
#   'effect',
#   'assay',
#   'result',
#   'protect',
#   'express',
#   'develop',
#   'neutral',
#   'high',
#   'studi',
#   'mous']]

# %%
"""Assign a topic to each of the papers."""

assigned_topic = []
for index, row in partial_df.iterrows():
    tokens = row["abstract tokens"]
    counter_array = [0] * 15
    for i in tokens:
        for j in np.arange(10):
            if i in topic_words[j]:
                counter_array[j] += 1
    max_topic = counter_array.index(max(counter_array))
    assigned_topic.append(max_topic)
                
partial_df["assigned topic"] = assigned_topic
partial_df = partial_df.sort_values("assigned topic")
partial_df
# Out:
#        Unnamed: 0                                       sha  \
# 13029       16652  4d1f6d57c9a112fb1afc5c8a819b293cf8146ee9
# 19707       20620  d11eb07952f5a0fb076a49935508707abeecf8af
# 25945       41462  168667e863cc79cb44157edf0e39ca66a37b2b7b
# 14660       28471  361e12416e0ff49f28521c2dc5fc69934e419910
# 16991       26797  14c6f99cf0ec54c78447ad5a8403e3ee2708176f
# ...           ...                                       ...
# 8527        11015  a61e707ef1a808123b3c6f542a79373d4315d603
# 23315       24268  12329a694934f5824e1ef7d695a7a1fa0310f52c
# 23313       24266  a02952893a51f2255a8d9d84b3eba6fe1b113996
# 8524        11012  866943e037d3b683d0405a9d65d94568074ed592
# 0               3  aecbc613ebdab36753235197ffb4f35734b5ca63
#
#                                                 abstract  \
# 13029  Exosomes are small membrane vesicles that are ...
# 19707  Idiopathic renal hypouricaemia is an inherited...
# 25945  BACKGROUND: Nosocomial, or healthcare-associat...
# 14660  Severe acute respiratory syndrome (SARS) poses...
# 16991  Background For 20 years, China has participate...
# ...                                                  ...
# 8527   Abstract Cellular immune response plays an imp...
# 23315  INTRODUCTION: The ability to predict epitopes ...
# 23313  We designed and produced a self-assembling pro...
# 8524   Abstract The severe acute respiratory syndrome...
# 0      Abstract Middle-aged female identical twins, o...
#
#                                          abstract tokens  assigned topic
# 13029  [exosom, small, membran, vesicl, secret, multi...               0
# 19707  [idiopath, renal, hypouricaemia, inherit, form...               0
# 25945  [background, nosocomi, healthcare-associ, infe...               0
# 14660  [sever, acut, respiratori, syndrom, sar, pose,...               0
# 16991  [background, year, china, particip, intern, co...               0
# ...                                                  ...             ...
# 8527   [cellular, immun, respons, play, import, role,...               9
# 23315  [introduct, abil, predict, epitop, play, enorm...               9
# 23313  [design, produc, self-assembl, protein, nanopa...               9
# 8524   [sever, acut, respiratori, syndrom, coronaviru...               9
# 0      [middle-ag, femal, ident, twin, system, lupus,...               9
#
# [24045 rows x 5 columns]

# %%
cluster3 = partial_df[partial_df["assigned topic"] == 9]
abstractStrings = cluster3.sample(100)["abstract"].values
wordCloudString = ""
for i in np.arange(100):
    wordCloudString += abstractStrings[i]
    
from PIL import Image
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
    
# lower max_font_size, change the maximum number of word and lighten the background:
wordcloud = WordCloud(max_font_size=50, max_words=20, background_color="white").generate(wordCloudString)
plt.figure()
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show()

# %%
partial_df.to_csv("document_clusters.csv")
